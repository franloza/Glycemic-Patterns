# %% [markdown]
# # Patient report
# ## Patient ID: DSG
# ## Dates: 30/01/2016 - 30/06/2016

# %%
from app import app
from IPython.display import Image
app('data/DSG_20160130_20160630_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# <div class="alert alert-block alert-warning">The number of carbohydrate registers (Type 5) is less than 1 per day. Patterns may not be accurate</div>
# ============Patrones de hiperglucemia=============
# Reglas:
# 	Nivel de glucosa máximo del día anterior es menor o igual que 249.5
# Muestras: 1550 (16.92%)
# Impureza: 0.05759
# Número de muestras positivas: 1504
# Número de muestras negativas: 46
#
#
# Reglas:
# 	Nivel de glucosa máximo del día anterior es mayor que 260.5
# 	Hora de la última comida es menor o igual que 14.5
# Muestras: 1409 (15.38%)
# Impureza: 0.2713
# Número de muestras positivas: 1181
# Número de muestras negativas: 228
#
#
# Reglas:
# 	Nivel de glucosa máximo del día anterior es mayor que 260.5
# 	Variabilidad glucémica (MAGE) del día anterior es menor o igual que 202
# 	Hora de la última comida es mayor que 14.5
# 	Minutos transcurridos desde la última comida es menor o igual que 7574
# Muestras: 915 (9.99%)
# Impureza: 0.04901
# Número de muestras positivas: 892
# Número de muestras negativas: 23
#
#
# Reglas:
# 	Nivel de glucosa máximo del día anterior es mayor que 260.5
# 	Variabilidad glucémica (MAGE) del día anterior es menor o igual que 202
# 	Hora de la última comida es mayor que 14.5
# 	Minutos transcurridos desde la última comida es mayor que 7574
# Muestras: 3065 (33.46%)
# Impureza: 0
# Número de muestras positivas: 3065
# Número de muestras negativas: 0
#
#
# Reglas:
# 	Nivel de glucosa máximo del día anterior es mayor que 260.5
# 	Variabilidad glucémica (MAGE) del día anterior es mayor que 202
# 	Hora de la última comida es mayor que 14.5
# Muestras: 1270 (13.87%)
# Impureza: 0.1028
# Número de muestras positivas: 1201
# Número de muestras negativas: 69
#
#
# =============Patrones de hipoglucemia=============
# Reglas:
# 	Insulina de acción rápida (unidades) del bloque anterior es menor o igual que 7
# 	Día de la semana es menor o igual que 3.5
# 	Desviación estandar del nivel de glucosa del día anterior es menor o igual que 65.45
# 	Minutos transcurridos desde la última comida es menor o igual que 7.622e+04
# Muestras: 1439 (15.71%)
# Impureza: 0.04878
# Número de muestras positivas: 1403
# Número de muestras negativas: 36
#
#
# Reglas:
# 	Insulina de acción rápida (unidades) del bloque anterior es menor o igual que 7
# 	Día de la semana es mayor que 3.5
# 	Nivel de glucosa mínimo del día anterior es menor o igual que 48.5
# 	Minutos transcurridos desde la última comida es menor o igual que 3.114e+04
# Muestras: 1351 (14.75%)
# Impureza: 0.09293
# Número de muestras positivas: 1285
# Número de muestras negativas: 66
#
#
# Reglas:
# 	Insulina de acción rápida (unidades) del bloque anterior es menor o igual que 7
# 	Día de la semana es mayor que 3.5
# 	Variabilidad glucémica (MAGE) del día anterior es menor o igual que 110.2
# 	Nivel de glucosa mínimo del día anterior es mayor que 48.5
# Muestras: 915 (9.99%)
# Impureza: 0.05108
# Número de muestras positivas: 891
# Número de muestras negativas: 24
#
#
# Reglas:
# 	Insulina de acción rápida (unidades) del bloque anterior es menor o igual que 7
# 	Día de la semana es mayor que 3.5
# 	Variabilidad glucémica (MAGE) del día anterior es mayor que 110.2
# 	Nivel de glucosa mínimo del día anterior es mayor que 48.5
# Muestras: 1117 (12.20%)
# Impureza: 0
# Número de muestras positivas: 1117
# Número de muestras negativas: 0
#
#
# =========Patrones de hiperglucemia severa=========
# Reglas:
# 	Nivel de glucosa máximo del día anterior es menor o igual que 249.5
# 	Minutos transcurridos desde la última comida es mayor que 1.948e+04
# 	Nivel de glucosa máximo del bloque anterior es menor o igual que 342.5
# Muestras: 941 (10.27%)
# Impureza: 0.008465
# Número de muestras positivas: 937
# Número de muestras negativas: 4
#
#
# Reglas:
# 	Minutos transcurridos desde la última comida es menor o igual que 5.739e+04
# 	Nivel de glucosa máximo del bloque anterior es mayor que 342.5
# Muestras: 915 (9.99%)
# Impureza: 0.1431
# Número de muestras positivas: 844
# Número de muestras negativas: 71
#
#
# Reglas:
# 	Minutos transcurridos desde la última comida es mayor que 5.739e+04
# 	Nivel de glucosa máximo del bloque anterior es mayor que 342.5
# Muestras: 1026 (11.20%)
# Impureza: 0
# Número de muestras positivas: 1026
# Número de muestras negativas: 0

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")
