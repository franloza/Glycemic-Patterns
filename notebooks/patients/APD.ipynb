# %% [markdown]
# # Patterns report
# ### Patient ID: APD
# ### Dates: 20/06/2016 - 04/07/2016

# %%
from app import app
from IPython.display import Image
app('data/APD_20160620_20160704_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# <div class="alert alert-block alert-warning">The number of carbohydrate registers (Type 5) is less than 1 per day. Patterns may not be accurate</div>
# <div class="alert alert-block alert-danger">Patrones de hiperglucemia : The decision tree only consists of a root node. Patterns can't be defined</div>
# =============Patrones de hipoglucemia=============
# Reglas:
# 	Desviación estandar del nivel de glucosa del bloque anterior es menor o igual que 60.13
# 	Día de la semana es mayor que 2.5
# Muestras: 758 (63.43%)
# Impureza: 0
# Número de muestras positivas: 758
# Número de muestras negativas: 0
#
#
# =========Patrones de hiperglucemia severa=========
# Reglas:
# 	Minutos transcurridos desde la última comida es menor o igual que 7806
# Muestras: 436 (36.49%)
# Impureza: 0
# Número de muestras positivas: 436
# Número de muestras negativas: 0
#
#
# Reglas:
# 	Media del nivel de glucosa del día anterior es mayor que 166.5
# ...

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")

# %% [markdown]
# ### Patient ID: APD
# ### Dates: 06/07/2016 - 21/07/2016

# %%
app('data/APD_20160706_20160721_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# ============Patrones de hiperglucemia=============
# Reglas:
# 	Media del nivel de glucosa del día anterior es menor o igual que 136.4
# 	Media del nivel de glucosa del bloque anterior es menor o igual que 163
# 	Variabilidad glucémica (MAGE) del día anterior es menor o igual que 110
# Muestras: 490 (40.60%)
# Impureza: 0
# Número de muestras positivas: 490
# Número de muestras negativas: 0
#
#
# =============Patrones de hipoglucemia=============
# Reglas:
# 	Media del nivel de glucosa del bloque anterior es mayor que 118.1
# 	Nivel de glucosa mínimo del día anterior es menor o igual que 56.5
# 	Desviación estandar del nivel de glucosa del bloque anterior es menor o igual que 39.9
# 	Media del nivel de glucosa del día anterior es mayor que 124.3
# Muestras: 125 (10.36%)
# Impureza: 0
# Número de muestras positivas: 125
# Número de muestras negativas: 0
#
#
# Reglas:
# 	Nivel de glucosa mínimo del día anterior es mayor que 56.5 y es menor o igual que 68
# ...

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")

# %% [markdown]
# ### Patient ID: APD
# ### Dates: 20/06/2016 - 04/07/2016 and 06/07/2016 - 21/07/2016

# %%
app(['data/APD_20160620_20160704_FREE_STYLE.txt',
     'data/APD_20160706_20160721_FREE_STYLE.txt']
    , max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# <div class="alert alert-block alert-warning">The number of carbohydrate registers (Type 5) is less than 1 per day. Patterns may not be accurate</div>
# ============Patrones de hiperglucemia=============
# Reglas:
# 	Media del nivel de glucosa del día anterior es menor o igual que 126.4
# 	Minutos transcurridos desde la última comida es menor o igual que 810.5
# Muestras: 309 (12.86%)
# Impureza: 0.1097
# Número de muestras positivas: 291
# Número de muestras negativas: 18
#
#
# Reglas:
# 	Hora de la última comida es mayor que 11.5
# 	Minutos transcurridos desde la última comida es mayor que 810.5 y es menor o igual que 2474
# Muestras: 288 (11.99%)
# Impureza: 0.2491
# Número de muestras positivas: 246
# Número de muestras negativas: 42
#
#
# Reglas:
# 	Hora de la última comida es mayor que 11.5
# 	Minutos transcurridos desde la última comida es mayor que 2474
# Muestras: 1118 (46.54%)
# Impureza: 0
# Número de muestras positivas: 1118
# Número de muestras negativas: 0
#
#
# ...

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")
