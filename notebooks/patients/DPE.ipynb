# %% [markdown]
# # Patient report
# ## Patient ID: DPE
# ## Dates: 20/05/2016 - 03/08/2016

# %%
from app import app
from IPython.display import Image
app('data/DPE_20160520_20160803_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# <div class="alert alert-block alert-warning">The number of carbohydrate registers (Type 5) is less than 1 per day. Patterns may not be accurate</div>
# ============Patrones de hiperglucemia=============
# Reglas:
# 	Minutos transcurridos desde la última comida es menor o igual que 5306
# 	Desviación estandar del nivel de glucosa del bloque anterior es menor o igual que 61.32
# Muestras: 743 (33.67%)
# Impureza: 0
# Número de muestras positivas: 743
# Número de muestras negativas: 0
#
#
# Reglas:
# 	Minutos transcurridos desde la última comida es mayor que 5306
# 	Desviación estandar del nivel de glucosa del bloque anterior es menor o igual que 61.32
# Muestras: 220 (9.97%)
# Impureza: 0.04442
# Número de muestras positivas: 215
# Número de muestras negativas: 5
#
#
# Reglas:
# 	Minutos transcurridos desde la última comida es menor o igual que 3900
# 	Desviación estandar del nivel de glucosa del día anterior es mayor que 75.22
# ...

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")

# %% [markdown]
# Problem: Not enough registers of carbohydrates lead to a poor definition of blocks, leading to strange patterns such as 'Ellapsed minutes since last meal is greater than 5380'. A warning is set for this case
