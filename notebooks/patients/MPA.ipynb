# %% [markdown]
# # Patterns report
# ### Patient ID: MPA
# ### Dates: 04/04/2016 - 28/04/2016

# %%
from app import app
from IPython.display import Image
app('data/MPA_20160404_20160428_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# <div class="alert alert-block alert-danger">There are periods of time of more than one day without data</div>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# <div class="alert alert-block alert-warning">To exit: use 'exit', 'quit', or Ctrl-D.</div>

# %% [markdown]
# ### Patient ID: MPA
# ### Dates: 13/04/2016 - 27/04/2016

# %%
app('data/MPA_20160413_20160427_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')

# %% [markdown]
# ### Patient ID: MPA
# ### Dates: 25/05/2016 - 28/05/2016

# %%
app('data/MPA_20160525_20160528_FREE_STYLE.txt', max_impurity=0.3, output_path="notebooks/patients", language='es')
# Out:
# ============Patrones de hiperglucemia=============
# Reglas:
# 	Media del nivel de glucosa del bloque anterior es menor o igual que 175.6
# 	Nivel de glucosa máximo del bloque anterior es menor o igual que 223
# Muestras: 128 (53.33%)
# Impureza: 0
# Número de muestras positivas: 128
# Número de muestras negativas: 0
#
#
# =============Patrones de hipoglucemia=============
# Reglas:
# 	Nivel de glucosa mínimo del bloque anterior es menor o igual que 91.5
# Muestras: 111 (46.25%)
# Impureza: 0
# Número de muestras positivas: 111
# Número de muestras negativas: 0
#
#
# =========Patrones de hiperglucemia severa=========
# Reglas:
# 	Desviación estandar del nivel de glucosa del bloque anterior es mayor que 22.72 y es menor o igual que 29.17
# Muestras: 32 (13.33%)
# Impureza: 0
# Número de muestras positivas: 32
# Número de muestras negativas: 0

# %%
Image("notebooks/patients/Hyperglycemia_Tree.png")

# %%
Image("notebooks/patients/Hypoglycemia_Tree.png")

# %%
Image("notebooks/patients/Severe_Hyperglycemia_Tree.png")
